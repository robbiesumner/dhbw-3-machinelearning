# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Übungsaufgaben 2

# %%
advertising = pd.read_csv('advertising_data.csv')
advertising.head()
# Out:
#    Market     TV  radio  newspaper  sales
# 0       1  230.1   37.8       69.2   22.1
# 1       2   44.5   39.3       45.1   10.4
# 2       3   17.2   45.9       69.3    9.3
# 3       4  151.5   41.3       58.5   18.5
# 4       5  180.8   10.8       58.4   12.9

# %% [markdown]
# ## Lineare Regression: `sales ~ TV`

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split

# %%
X = advertising['TV'].values.reshape(-1,1)
y = advertising['sales'].values.reshape(-1,1)
X.shape, y.shape
# Out:
# ((200, 1), (200, 1))

# %%
a0_list = []
a1_list = []
train_mqa_list = []
test_mqa_list = []

for i in range(50):
    print(f"Versuch {i+1}")
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=i)

    regressor = LinearRegression()
    regressor.fit(X_train, y_train)
    print("    Koeffizienten der Regressiongerade: ")
    print(f"        a0: {regressor.intercept_[0]}")
    print(f"        a1: {regressor.coef_[0][0]}")

    # error
    train_mqa = np.mean((y_train - regressor.predict(X_train)) ** 2)
    print(f"    Train MQA: {train_mqa}")
    test_mqa = np.mean((y_test - regressor.predict(X_test)) ** 2)
    print(f"    Test MQA: {test_mqa}")

    a0_list.append(regressor.intercept_[0])
    a1_list.append(regressor.coef_[0][0])
    train_mqa_list.append(train_mqa)
    test_mqa_list.append(test_mqa)

    # Plotten
    plt.xlabel('TV ($)')
    plt.ylabel('Sales ($)')
    plt.scatter(X_train, y_train, color='yellow')
    plt.scatter(X_test, y_test, color='blue')
    plt.legend(['Train', 'Test'])
    plt.plot(X_train, regressor.predict(X_train), color='red', linewidth=2)
    plt.show()
# Out:
# Versuch 1
#     Koeffizienten der Regressiongerade:
#         a0: 7.292493773559357
#         a1: 0.046007789603017206
#     Train MQA: 10.617238416139852
#     Test MQA: 10.186181934530214
# Versuch 2
#     Koeffizienten der Regressiongerade:
#         a0: 6.799773449796854
#         a1: 0.049275095667046034
#     Train MQA: 10.454336617171425
#     Test MQA: 10.859345325608269
# Versuch 3
#     Koeffizienten der Regressiongerade:
#         a0: 6.566524608650464
#         a1: 0.05245828085802822
#     Train MQA: 8.99761678931429
#     Test MQA: 17.79289350579991
# Versuch 4
#     Koeffizienten der Regressiongerade:
#         a0: 6.9542511962420175
#         a1: 0.04729254254748589
#     Train MQA: 10.310414011789058
#     Test MQA: 11.389041805489907
# Versuch 5
#     Koeffizienten der Regressiongerade:
#         a0: 6.865601946946056
#         a1: 0.04810780532858888
#     Train MQA: 9.886852832059859
#     Test MQA: 13.06226628830567
# Versuch 6
# ...

# %% [markdown]
# ### Histogramme

# %%
plt.hist(a0_list)
plt.xlabel('a0')
plt.show()

# %%
plt.hist(a1_list)
plt.xlabel('a1')
plt.show()

# %%
plt.hist(train_mqa_list)
plt.xlabel('Train MQA')
plt.show()

# %%
plt.hist(test_mqa_list)
plt.xlabel('Test MQA')
plt.show()

# %% [markdown]
# ## Lineare Regression mit TV und Radio und Newspaper

# %%
# model with all three variables
X = advertising.drop(['sales', 'Market'], axis=1)
y = advertising['sales'].values.reshape(-1,1)
X.shape, y.shape
# Out:
# ((200, 3), (200, 1))

# %%
X
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
for i in range(50):
    print(f"Versuch {i+1}")
    # split data
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=i)

    regressor = LinearRegression()
    regressor.fit(X_train, y_train)

    print("    Koeffizienten der Regressiongerade: ")
    print(f"        a0: {regressor.intercept_[0]}")
    # print all coefficients with variable names
    for i in range(len(X.columns)):
        print(f"        {X.columns[i]}: {regressor.coef_[0][i]}")

    # error
    train_mqa = np.mean((y_train - regressor.predict(X_train)) ** 2)
    print(f"    Train MQA: {train_mqa}")
    test_mqa = np.mean((y_test - regressor.predict(X_test)) ** 2)
    print(f"    Test MQA: {test_mqa}")
# Out:
# Versuch 1
#     Koeffizienten der Regressiongerade:
#         a0: 2.9948930304953265
#         TV: 0.04458402011996432
#         radio: 0.196497034155405
#         newspaper: -0.002781463981926014
#     Train MQA: 2.406814755818906
#     Test MQA: 4.402118291449682
# Versuch 2
#     Koeffizienten der Regressiongerade:
#         a0: 2.907947020816433
#         TV: 0.04684310317699042
#         radio: 0.17854434380887607
#         newspaper: 0.00258618609398899
#     Train MQA: 3.016830607659678
#     Test MQA: 1.9918855518287901
# Versuch 3
#     Koeffizienten der Regressiongerade:
#         a0: 3.0544520115813842
#         TV: 0.04735257168501801
#         radio: 0.17323832458475988
#         newspaper: 0.00466518720051937
#     Train MQA: 2.469205292181748
#     Test MQA: 4.5031259450461265
# Versuch 4
#     Koeffizienten der Regressiongerade:
#         a0: 2.910980862854185
#         TV: 0.045529170091442056
#         radio: 0.1851240304385768
# ...
